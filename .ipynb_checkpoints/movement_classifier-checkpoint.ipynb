# %% [markdown]
# # Inertial Data Classification using SVM
#
# This notebook demonstrates an end-to-end pipeline for classifying inertial sensor data.
# It covers:
# 1. Data exploration
# 2. Feature extraction
# 3. Feature filtering
# 4. Model training (SVM)
# 5. Evaluation and insights

# %%
# Imports
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from src.extractfilesfinal import extract
from src.Short_features import filter_features
from src.SVM_Leave_one_out import train_and_evaluate
import glob

# %%
files = glob.glob("data_raw/*.txt")
print(f"{len(files)} files found.")
sample_file = files[0]

# Example preview
with open(sample_file, 'r') as f:
    for _ in range(10):
        print(f.readline().strip())
